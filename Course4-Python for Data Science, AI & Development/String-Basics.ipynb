# %% [markdown]
#  # PYTHON EXPRESSIONS, VARIABLES, STRINGS

# %% [markdown]
# ## Strings Basics

# %%
# introduced in Python 3.6, f-strings are a new way to format strings in Python. 
# They are prefixed with 'f' and use curly braces {} to enclose the variables that will be formatted.

name = "John"
age = 30
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is John and I am 30 years old

# %%
name = "John"
age = 30
print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is John and I am 30 years old.

# %%
name = "John"
age = 30
print("My name is %s and I am %d years old." % (name, age))
# Out:
# My name is John and I am 30 years old.

# %%
# Raw String (r")

regular_string = "C:\new_folder\file.txt"
print("Regular String:", regular_string)
# Out:
# Regular String: C:
# ew_folderile.txt

# %%
raw_string = r"C:\new_folder\file.txt"
print("Raw String:", raw_string)
# Out:
# Raw String: C:\new_folder\file.txt

# %% [markdown]
# ## Expressions

# %%
43 + 60 +16 + 41
# Out:
# 160

# %%
50 - 60
# Out:
# -10

# %%
5 * 5
# Out:
# 25

# %%
25 / 5
# Out:
# 5.0

# %%
25 / 6
# Out:
# 4.166666666666667

# %%
# Using double slash gives the result as rounded down to the nearest integer.

25 // 5
# Out:
# 5

# %%
25 // 6
# Out:
# 4

# %%
160 // 60
# Out:
# 2

# %%
(30 + 2) * 60
# Out:
# 1920

# %% [markdown]
# ## Variables

# %%
x = 43 + 60 +16 + 41
print(x)
# Out:
# 160

# %%
print(x)
# Out:
# 160

# %%
y = x / 60
y
# Out:
# 2.6666666666666665

# %%
x = x / 60
x
# Out:
# 2.6666666666666665

# %%
total_min = 43 + 42 + 57 
total_min
# Out:
# 142

# %%
total_hours = total_min / 60
total_hours
# Out:
# 2.3666666666666667

# %%
total_hours = (43 + 42 + 57) / 60
total_hours
# Out:
# 2.3666666666666667

# %% [markdown]
# Write an expression to add 30 and 20 and subtract 40

# %%
30 + 20 - 40
# Out:
# 10

# %% [markdown]
# Write an expression to subtract 5 from 55 and divide the result by 10

# %%
(55 - 5)/10
# Out:
# 5.0

# %% [markdown]
# Write an expression to multiply 6 with 10 and divide the result by 12

# %%
(6 * 10) / 12
# Out:
# 5.0

# %% [markdown]
# What is the value of x where x = 3 + 2 * 2

# %%
x = 3 + 2 * 2
x
# Out:
# 7

# %% [markdown]
# What is the value of y where y = (3 + 2) * 2?

# %%
y = (3 + 2) * 2
y
# Out:
# 10

# %% [markdown]
# What is the value of z where z = x + y?

# %%
z = x + y
z
# Out:
# 17
