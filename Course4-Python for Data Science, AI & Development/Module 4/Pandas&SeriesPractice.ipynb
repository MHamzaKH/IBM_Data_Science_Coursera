# %%
import pandas as pd

# %%
# Read the CSV file into a DataFrame

df = pd.read_csv('/Users/pro_jects/Desktop/currency.csv')

# %%
# Series is a one dimentional labeled array in Pandas. it can be thought of as a single column of data with labels or indices for each element.
# You can create a Series from various data sources, such as lists, NumPy arrays, or dictionaries

# Create a Series from a list

data = [10,20,30,40,50]
s = pd.Series(data)

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(s[2])
# Out:
# 30

# %%
print(s.iloc[3])
# Out:
# 40

# %%
print(s[1:4])
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.shape
# Out:
# (5,)

# %%
s.size
# Out:
# 5

# %%
s.mean()
# Out:
# 30.0

# %%
s.unique()
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.nunique()
# Out:
# 5

# %%
s.sort_values
# Out:
# <bound method Series.sort_values of 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64>

# %%
s.sort_index
# Out:
# <bound method Series.sort_index of 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64>

# %%
# Data-Frame is 2 dimentional labeled data strcuture with columns of potentially different data types.
# Think of it as a table where each column represents a variable, and each row represents an observation or data point.
# DataFrames are suitable for a wide range of data, including structured data from CSV files, Excel spreadsheets, SQL databases, and more.

import pandas as pd

# Creating DataFrame from a dictionary
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25,30,35,28],
        'city': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age           city
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
# Column Selection:


print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object

# %%
print(df.iloc[2])
# Out:
# Name        Charlie
# Age              35
# city    Los Angeles
# Name: 2, dtype: object

# %%
print(df.iloc[3])
# Out:
# Name      David
# Age          28
# city    Chicago
# Name: 3, dtype: object

# %%
print(df.iloc[0])
# Out:
# Name       Alice
# Age           25
# city    New York
# Name: 0, dtype: object

# %%
# Slicing

print(df[['Name','Age']])
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   28

# %%
print(df[1:3])
# Out:
#       Name  Age           city
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles

# %%
unique_dates = df['Age'].unique()
unique_dates
# Out:
# array([25, 30, 35, 28])

# %%
high_above_102 = df[df['Age'] > 25]
high_above_102
# Out:
#       Name  Age           city
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
# saving Data Frame

df.to_csv('trading_data.csv', index=False)

# %%
df.shape
# Out:
# (4, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   29.500000
# std     4.203173
# min    25.000000
# 25%    27.250000
# 50%    29.000000
# 75%    31.250000
# max    35.000000

# %%
df.head()
# Out:
#       Name  Age           city
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
df.tail()
# Out:
#       Name  Age           city
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
print("Mean = ", df.mean())
print("sum = ", df.sum())
print("min = ", df.min())
print("max = ", df.max())
# Out:
# Mean =  Age    29.5
# dtype: float64
# sum =  Name                       AliceBobCharlieDavid
# Age                                         118
# city    New YorkSan FranciscoLos AngelesChicago
# dtype: object
# min =  Name      Alice
# Age          25
# city    Chicago
# dtype: object
# max =  Name            David
# Age                35
# city    San Francisco
# dtype: object
# /var/folders/jl/8dyc06c55jj94k3z28ctgnzw0000gp/T/ipykernel_4334/72276996.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print("Mean = ", df.mean())
